# %%
import pandas as pd
import bokeh as bk
import seaborn as sb
# %matplotlib inline
from bokeh.plotting import *
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.models.glyphs import Line as Line_glyph, Oval
from bokeh.models import Range1d, LinearAxis, FactorRange, LabelSet
#from bokeh.charts import Bar, Scatter, BoxPlot
#from bokeh.charts.attributes import cat
from bokeh.layouts import gridplot
import numpy as np
pd.options.display.max_rows = 50
pd.options.display.max_columns = 999

# %%
mozilla_df = pd.read_csv("mozilla-filt-coded.csv", encoding = "iso-8859_1", low_memory = False)
mozilla_df = mozilla_df.fillna(0)
mozilla_df
# Out:
#         Response ID                       Country  I consider myself:  \
# 0                 1                 United States                 2.0
# 1                 2                 United States                 2.0
# 2                 3                 United States                 2.0
# 3                 4                 United States                 2.0
# 4                 5                        Canada                 2.0
# 5                 6                 United States                 2.0
# 6                 7                 United States                 2.0
# 7                 8                        Canada                 1.0
# 8                 9                 United States                 2.0
# 9                10                 United States                 2.0
# 10               11                 United States                 2.0
# 11               12                 United States                 2.0
# ...

# %%
raw_df = mozilla_df[['What are you most excited about as we move toward a more digitally connected future?']].copy()
raw_df
# Out:
#         What are you most excited about as we move toward a more digitally connected future?
# 0                                                     0.0
# 1                                                     0.0
# 2                                                     1.0
# 3                                                     2.0
# 4                                                     0.0
# 5                                                     1.0
# 6                                                     2.0
# 7                                                     3.0
# 8                                                     1.0
# 9                                                     2.0
# 10                                                    1.0
# 11                                                    0.0
# 12                                                    4.0
# 13                                                    0.0
# 14                                                    0.0
# ...

# %%
raw_df.describe()
# Out:
#        What are you most excited about as we move toward a more digitally connected future?
# count                                      192654.000000
# mean                                            2.165244
# std                                             1.789366
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                             5.000000

# %%
count_df = raw_df.apply(pd.value_counts)
# Out:
#      What are you most excited about as we move toward a more digitally connected future?
# 0.0                                              61602
# 4.0                                              47943
# 3.0                                              26318
# 2.0                                              26146
# 5.0                                              15870
# 1.0                                              14775

# %%
#Calculating Sums of Devices owned per group
g1 = graph_df[graph_df['What is your biggest fear as we move towards a more connected future?'] == 'The loss of privacy']
print (g1['Total Devices Owned'].sum())
g2 = graph_df[graph_df['What is your biggest fear as we move towards a more connected future?'] == 'WeÛªll lose touch with one another']
print (g2['Total Devices Owned'].sum())
g3 = graph_df[graph_df['What is your biggest fear as we move towards a more connected future?'] == 'WeÛªll be less safe']
print (g3['Total Devices Owned'].sum())
g4 = graph_df[graph_df['What is your biggest fear as we move towards a more connected future?'] == 'Other (please specify)']
print (g4['Total Devices Owned'].sum())
g5 = graph_df[graph_df['What is your biggest fear as we move towards a more connected future?'] == 'I have no fears about a more connected future']
print (g5['Total Devices Owned'].sum())
# Out:
# 268252.0
# 133344.0
# 86014.0
# 47270.0
# 44688.0

# %%
top = [61602,14775,26146,26318,47943,15870]

# %%
#RQ What are you most excited about as we move toward a more digitally connected future?
output_file("Visualization #4.html")

categories = ["None of the above","How much fun it will be","How it will bring the world together","How it will make us all smarter and better educated","How easy it will make life","Other (please specify)"]

#Interactivity
hover = HoverTool(tooltips=[
    ("Option", "@x"),
    ("The amount of Option", "@top"),
])


p = figure(x_range = categories, plot_height = 500, plot_width = 1000, title = "How people are excited about as we move toward a more digitally connected future?", tools = [hover])
p.vbar(x = categories, top = [61602,14775,26146,26318,47943,15870], width = 0.5)

#p.xaxis.axis_label = "What are you most excited about as we move toward a more digitally connected future?"
p.yaxis.axis_label = " Amount of Vote"


g = gridplot([[p]], toolbar_location=None)


show(g)
# Out:
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='2cd4d400-e816-4e0c-b80f-47deb70b87f8', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='a0b27489-9836-47d1-8fa4-e723bc01b7b7', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='26987704-bbd6-4f6d-8da5-fff4769f45c5', ...)
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='a5732569-78fe-4b90-ae13-feb60b070404', ...)
